# %%
import segmentation_models as sm
from sklearn.model_selection import train_test_split

from brainseg.generator import TrainGenerator, TestGenerator
from brainseg.loader import Loader
from brainseg.utils import load_data, show_batch
from brainseg.image_provider import ImageHandler
from brainseg.provider import provider
from brainseg.streamlit.manager import list_all

import matplotlib.pyplot as plt
import numpy as np
import imgaug.augmenters as iaa
from imgaug.augmentables.segmaps import SegmentationMapsOnImage
from tensorflow.keras.optimizers import Adam
from skimage.transform import resize

sm.set_framework("tf.keras")
# Out:
# 2022-06-07 15:17:16.995248: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-07 15:17:16.995275: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Segmentation Models: using `keras` framework.

# %%
from brainseg.deepunet2 import unet_model

# %%
model = unet_model(n_classes=1, im_sz=576, n_channels=3, n_filters_start=32, growth_factor=1.2, upconv=True)
model.compile(
    Adam(learning_rate=1e-4),
    loss=sm.losses.bce_jaccard_loss,
    metrics=[sm.metrics.iou_score],
)
# Out:
# 2022-06-07 15:17:20.089865: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nathan/.cache/pypoetry/virtualenvs/brainseg-XuOkmMtq-py3.8/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-07 15:17:20.089896: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-07 15:17:20.089917: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (nathan-SBRI): /proc/driver/nvidia/version does not exist

# %%
sh = ImageHandler()
provider.register(sh)

# %%
seq = iaa.Sequential([
    iaa.Invert(),
    iaa.Fliplr(0.5),
    iaa.Flipud(0.5),
    iaa.Rot90([0, 1, 2, 3]),
    iaa.Affine(
        scale={"x": (0.9, 1.1), "y": (0.9, 1.1)},
        translate_percent={"x": (-0.1, 0.1), "y": (-0.1, 0.1)},
        rotate=(-10, 10),
        shear=(-4, 4),
        cval=255,
    ),
    iaa.Invert(),
])

# %%
def preprocess_augment(x, y):
    x = np.asarray(x)
    y = 255 - np.asarray(y)
    
    seg = SegmentationMapsOnImage(y, shape=y.shape)
    x, y = seq(image=x, segmentation_maps=seg)
    y = 255 - y.arr
    x = x / 255.
    y = y / 255.
    x = resize(x, (576, 576))
    y = resize(y, (576, 576))
    
    y = y.astype(np.float64)[:, :, :1]
    return x, y

# %%
def preprocess(x, y):
    x = np.asarray(x) / 255.
    y = np.asarray(y) / 255.
    x = resize(x, (576, 576))
    y = resize(y, (576, 576))
    y = y.astype(np.float64)[:, :, :1]
    # x, y = seq(image=x, segmentation_maps=y)
    return x, y

# %%
dataset = list_all("/media/nathan/LaCie/Data/wm_curated_x8_576/", min_threshold=10)

# %%
len(dataset)
# Out:
# 1004

# %%
s = list([x[1]["data_name"][:14] for x in dataset])
from collections import Counter
Counter(s)
# Out:
# Counter({'M148 LHRH312.c': 34,
#          'M148 LHRH266.c': 32,
#          'M148 LHRH278.c': 34,
#          'M148 LHRH264.c': 32,
#          'M148 LHRH268.c': 30,
#          'M148 LHRH232.c': 30,
#          'M148 LHRH252.c': 34,
#          'M148 LHRH296.c': 30,
#          'M148 LHRH244.c': 30,
#          'M148 LHRH292.c': 30,
#          'M148 LHRH300.c': 24,
#          'M148 LHRH304.c': 28,
#          'M148 LHRH316.c': 30,
#          'M148 LHRH320.c': 31,
#          'M148 LHRH280.c': 32,
#          'M148 LHRH302.c': 31,
#          'M148 LHRH254.c': 32,
#          'M148 LHRH310.c': 32,
#          'M148 LHRH248.c': 30,
#          'M148 LHRH314.c': 30,
#          'M148 LHRH240.c': 31,
#          'M148 LHRH318.c': 31,
#          'M148 LHRH306.c': 30,
#          'M148 LHRH256.c': 31,
#          'M148 LHRH272.c': 29,
#          'M148 LHRH286.c': 30,
#          'M148 LHRH260.c': 35,
#          'M148 LHRH308.c': 31,
#          'M148 LHRH258.c': 18,
#          'M148 LHRH236.c': 31,
#          'M148 LHRH288.c': 31,
#          'M148 LHRH276.c': 28,
#          'M148 LHRH284.c': 32})

# %%
print(len(dataset))
# Out:
# 1004

# %%
train_dataset, test_dataset = train_test_split(dataset, random_state=0)

# %%
len(train_dataset)
# Out:
# 753

# %%
train_gen = TrainGenerator(Loader(train_dataset), batch_size=4, preprocess=preprocess_augment)
test_gen = TestGenerator(Loader(test_dataset), batch_size=4, preprocess=preprocess)

# %%
show_batch(train_gen[0])

# %%
model = unet_model(n_classes=1, im_sz=576, n_channels=3, n_filters_start=32, growth_factor=1.2, upconv=True)
model.compile(
    Adam(learning_rate=1e-4),
    loss=sm.losses.bce_jaccard_loss,
    metrics=[sm.metrics.iou_score],
)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 576, 576, 3  0           []
#                                 )]
#
#  conv2d_64 (Conv2D)             (None, 576, 576, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_125 (Batch  (None, 576, 576, 32  128        ['conv2d_64[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_63 (LeakyReLU)     (None, 576, 576, 32  0           ['batch_normalization_125[0][0]']
#                                 )
#
#  leaky_re_lu_64 (LeakyReLU)     (None, 576, 576, 32  0           ['leaky_re_lu_63[0][0]']
#                                 )
#
#  batch_normalization_126 (Batch  (None, 576, 576, 32  128        ['leaky_re_lu_64[0][0]']
#  Normalization)                 )
#
#  conv2d_65 (Conv2D)             (None, 576, 576, 32  9248        ['batch_normalization_126[0][0]']
#                                 )
#
#  batch_normalization_128 (Batch  (None, 576, 576, 32  128        ['conv2d_65[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_65 (LeakyReLU)     (None, 576, 576, 32  0           ['batch_normalization_128[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 576, 576, 32  9248        ['leaky_re_lu_65[0][0]']
#                                 )
#
#  batch_normalization_129 (Batch  (None, 576, 576, 32  128        ['conv2d_66[0][0]']
#  Normalization)                 )
#
#  batch_normalization_127 (Batch  (None, 576, 576, 32  128        ['leaky_re_lu_63[0][0]']
#  Normalization)                 )
#
#  add_25 (Add)                   (None, 576, 576, 32  0           ['batch_normalization_129[0][0]',
#                                 )                                 'batch_normalization_127[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 288, 288, 32  0          ['add_25[0][0]']
#                                 )
#
#  dropout_12 (Dropout)           (None, 288, 288, 32  0           ['max_pooling2d_6[0][0]']
#                                 )
#
#  batch_normalization_130 (Batch  (None, 288, 288, 32  128        ['dropout_12[0][0]']
#  Normalization)                 )
#
#  conv2d_67 (Conv2D)             (None, 288, 288, 38  10982       ['batch_normalization_130[0][0]']
#                                 )
#
#  batch_normalization_131 (Batch  (None, 288, 288, 38  152        ['conv2d_67[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_66 (LeakyReLU)     (None, 288, 288, 38  0           ['batch_normalization_131[0][0]']
#                                 )
#
#  leaky_re_lu_67 (LeakyReLU)     (None, 288, 288, 38  0           ['leaky_re_lu_66[0][0]']
#                                 )
#
#  batch_normalization_132 (Batch  (None, 288, 288, 38  152        ['leaky_re_lu_67[0][0]']
#  Normalization)                 )
#
#  conv2d_68 (Conv2D)             (None, 288, 288, 38  13034       ['batch_normalization_132[0][0]']
#                                 )
#
#  batch_normalization_134 (Batch  (None, 288, 288, 38  152        ['conv2d_68[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_68 (LeakyReLU)     (None, 288, 288, 38  0           ['batch_normalization_134[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 288, 288, 38  13034       ['leaky_re_lu_68[0][0]']
#                                 )
#
#  batch_normalization_135 (Batch  (None, 288, 288, 38  152        ['conv2d_69[0][0]']
#  Normalization)                 )
#
#  batch_normalization_133 (Batch  (None, 288, 288, 38  152        ['leaky_re_lu_66[0][0]']
#  Normalization)                 )
#
#  add_26 (Add)                   (None, 288, 288, 38  0           ['batch_normalization_135[0][0]',
#                                 )                                 'batch_normalization_133[0][0]']
#
#  leaky_re_lu_69 (LeakyReLU)     (None, 288, 288, 38  0           ['add_26[0][0]']
#                                 )
#
#  batch_normalization_136 (Batch  (None, 288, 288, 38  152        ['leaky_re_lu_69[0][0]']
#  Normalization)                 )
#
#  conv2d_70 (Conv2D)             (None, 288, 288, 38  13034       ['batch_normalization_136[0][0]']
#                                 )
#
#  batch_normalization_138 (Batch  (None, 288, 288, 38  152        ['conv2d_70[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_70 (LeakyReLU)     (None, 288, 288, 38  0           ['batch_normalization_138[0][0]']
#                                 )
#
#  conv2d_71 (Conv2D)             (None, 288, 288, 38  13034       ['leaky_re_lu_70[0][0]']
#                                 )
#
#  batch_normalization_139 (Batch  (None, 288, 288, 38  152        ['conv2d_71[0][0]']
#  Normalization)                 )
#
#  batch_normalization_137 (Batch  (None, 288, 288, 38  152        ['add_26[0][0]']
#  Normalization)                 )
#
#  add_27 (Add)                   (None, 288, 288, 38  0           ['batch_normalization_139[0][0]',
#                                 )                                 'batch_normalization_137[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 144, 144, 38  0          ['add_27[0][0]']
#                                 )
#
#  dropout_13 (Dropout)           (None, 144, 144, 38  0           ['max_pooling2d_7[0][0]']
#                                 )
#
#  batch_normalization_140 (Batch  (None, 144, 144, 38  152        ['dropout_13[0][0]']
#  Normalization)                 )
#
#  conv2d_72 (Conv2D)             (None, 144, 144, 46  15778       ['batch_normalization_140[0][0]']
#                                 )
#
#  batch_normalization_141 (Batch  (None, 144, 144, 46  184        ['conv2d_72[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_71 (LeakyReLU)     (None, 144, 144, 46  0           ['batch_normalization_141[0][0]']
#                                 )
#
#  leaky_re_lu_72 (LeakyReLU)     (None, 144, 144, 46  0           ['leaky_re_lu_71[0][0]']
#                                 )
#
#  batch_normalization_142 (Batch  (None, 144, 144, 46  184        ['leaky_re_lu_72[0][0]']
#  Normalization)                 )
#
#  conv2d_73 (Conv2D)             (None, 144, 144, 46  19090       ['batch_normalization_142[0][0]']
#                                 )
#
#  batch_normalization_144 (Batch  (None, 144, 144, 46  184        ['conv2d_73[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_73 (LeakyReLU)     (None, 144, 144, 46  0           ['batch_normalization_144[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 144, 144, 46  19090       ['leaky_re_lu_73[0][0]']
#                                 )
#
#  batch_normalization_145 (Batch  (None, 144, 144, 46  184        ['conv2d_74[0][0]']
#  Normalization)                 )
#
#  batch_normalization_143 (Batch  (None, 144, 144, 46  184        ['leaky_re_lu_71[0][0]']
#  Normalization)                 )
#
#  add_28 (Add)                   (None, 144, 144, 46  0           ['batch_normalization_145[0][0]',
#                                 )                                 'batch_normalization_143[0][0]']
#
#  leaky_re_lu_74 (LeakyReLU)     (None, 144, 144, 46  0           ['add_28[0][0]']
#                                 )
#
#  batch_normalization_146 (Batch  (None, 144, 144, 46  184        ['leaky_re_lu_74[0][0]']
#  Normalization)                 )
#
#  conv2d_75 (Conv2D)             (None, 144, 144, 46  19090       ['batch_normalization_146[0][0]']
#                                 )
#
#  batch_normalization_148 (Batch  (None, 144, 144, 46  184        ['conv2d_75[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_75 (LeakyReLU)     (None, 144, 144, 46  0           ['batch_normalization_148[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 144, 144, 46  19090       ['leaky_re_lu_75[0][0]']
#                                 )
#
#  batch_normalization_149 (Batch  (None, 144, 144, 46  184        ['conv2d_76[0][0]']
#  Normalization)                 )
#
#  batch_normalization_147 (Batch  (None, 144, 144, 46  184        ['add_28[0][0]']
#  Normalization)                 )
#
#  add_29 (Add)                   (None, 144, 144, 46  0           ['batch_normalization_149[0][0]',
#                                 )                                 'batch_normalization_147[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 72, 72, 46)  0           ['add_29[0][0]']
#
#  dropout_14 (Dropout)           (None, 72, 72, 46)   0           ['max_pooling2d_8[0][0]']
#
#  batch_normalization_150 (Batch  (None, 72, 72, 46)  184         ['dropout_14[0][0]']
#  Normalization)
#
#  conv2d_77 (Conv2D)             (None, 72, 72, 55)   22825       ['batch_normalization_150[0][0]']
#
#  batch_normalization_151 (Batch  (None, 72, 72, 55)  220         ['conv2d_77[0][0]']
#  Normalization)
#
#  leaky_re_lu_76 (LeakyReLU)     (None, 72, 72, 55)   0           ['batch_normalization_151[0][0]']
#
#  leaky_re_lu_77 (LeakyReLU)     (None, 72, 72, 55)   0           ['leaky_re_lu_76[0][0]']
#
#  batch_normalization_152 (Batch  (None, 72, 72, 55)  220         ['leaky_re_lu_77[0][0]']
#  Normalization)
#
#  conv2d_78 (Conv2D)             (None, 72, 72, 55)   27280       ['batch_normalization_152[0][0]']
#
#  batch_normalization_154 (Batch  (None, 72, 72, 55)  220         ['conv2d_78[0][0]']
#  Normalization)
#
#  leaky_re_lu_78 (LeakyReLU)     (None, 72, 72, 55)   0           ['batch_normalization_154[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 72, 72, 55)   27280       ['leaky_re_lu_78[0][0]']
#
#  batch_normalization_155 (Batch  (None, 72, 72, 55)  220         ['conv2d_79[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 72, 72, 55)  220         ['leaky_re_lu_76[0][0]']
#  Normalization)
#
#  add_30 (Add)                   (None, 72, 72, 55)   0           ['batch_normalization_155[0][0]',
#                                                                   'batch_normalization_153[0][0]']
#
#  leaky_re_lu_79 (LeakyReLU)     (None, 72, 72, 55)   0           ['add_30[0][0]']
#
#  batch_normalization_156 (Batch  (None, 72, 72, 55)  220         ['leaky_re_lu_79[0][0]']
#  Normalization)
#
#  conv2d_80 (Conv2D)             (None, 72, 72, 55)   27280       ['batch_normalization_156[0][0]']
#
#  batch_normalization_158 (Batch  (None, 72, 72, 55)  220         ['conv2d_80[0][0]']
#  Normalization)
#
#  leaky_re_lu_80 (LeakyReLU)     (None, 72, 72, 55)   0           ['batch_normalization_158[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 72, 72, 55)   27280       ['leaky_re_lu_80[0][0]']
#
#  batch_normalization_159 (Batch  (None, 72, 72, 55)  220         ['conv2d_81[0][0]']
#  Normalization)
#
#  batch_normalization_157 (Batch  (None, 72, 72, 55)  220         ['add_30[0][0]']
#  Normalization)
#
#  add_31 (Add)                   (None, 72, 72, 55)   0           ['batch_normalization_159[0][0]',
#                                                                   'batch_normalization_157[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 36, 36, 55)  0           ['add_31[0][0]']
#
#  dropout_15 (Dropout)           (None, 36, 36, 55)   0           ['max_pooling2d_9[0][0]']
#
#  batch_normalization_160 (Batch  (None, 36, 36, 55)  220         ['dropout_15[0][0]']
#  Normalization)
#
#  conv2d_82 (Conv2D)             (None, 36, 36, 66)   32736       ['batch_normalization_160[0][0]']
#
#  batch_normalization_161 (Batch  (None, 36, 36, 66)  264         ['conv2d_82[0][0]']
#  Normalization)
#
#  leaky_re_lu_81 (LeakyReLU)     (None, 36, 36, 66)   0           ['batch_normalization_161[0][0]']
#
#  leaky_re_lu_82 (LeakyReLU)     (None, 36, 36, 66)   0           ['leaky_re_lu_81[0][0]']
#
#  batch_normalization_162 (Batch  (None, 36, 36, 66)  264         ['leaky_re_lu_82[0][0]']
#  Normalization)
#
#  conv2d_83 (Conv2D)             (None, 36, 36, 66)   39270       ['batch_normalization_162[0][0]']
#
#  batch_normalization_164 (Batch  (None, 36, 36, 66)  264         ['conv2d_83[0][0]']
#  Normalization)
#
#  leaky_re_lu_83 (LeakyReLU)     (None, 36, 36, 66)   0           ['batch_normalization_164[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 36, 36, 66)   39270       ['leaky_re_lu_83[0][0]']
#
#  batch_normalization_165 (Batch  (None, 36, 36, 66)  264         ['conv2d_84[0][0]']
#  Normalization)
#
#  batch_normalization_163 (Batch  (None, 36, 36, 66)  264         ['leaky_re_lu_81[0][0]']
#  Normalization)
#
#  add_32 (Add)                   (None, 36, 36, 66)   0           ['batch_normalization_165[0][0]',
#                                                                   'batch_normalization_163[0][0]']
#
#  leaky_re_lu_84 (LeakyReLU)     (None, 36, 36, 66)   0           ['add_32[0][0]']
#
#  batch_normalization_166 (Batch  (None, 36, 36, 66)  264         ['leaky_re_lu_84[0][0]']
#  Normalization)
#
#  conv2d_85 (Conv2D)             (None, 36, 36, 66)   39270       ['batch_normalization_166[0][0]']
#
#  batch_normalization_168 (Batch  (None, 36, 36, 66)  264         ['conv2d_85[0][0]']
#  Normalization)
#
#  leaky_re_lu_85 (LeakyReLU)     (None, 36, 36, 66)   0           ['batch_normalization_168[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 36, 36, 66)   39270       ['leaky_re_lu_85[0][0]']
#
#  batch_normalization_169 (Batch  (None, 36, 36, 66)  264         ['conv2d_86[0][0]']
#  Normalization)
#
#  batch_normalization_167 (Batch  (None, 36, 36, 66)  264         ['add_32[0][0]']
#  Normalization)
#
#  add_33 (Add)                   (None, 36, 36, 66)   0           ['batch_normalization_169[0][0]',
#                                                                   'batch_normalization_167[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 18, 18, 66)  0           ['add_33[0][0]']
#  )
#
#  dropout_16 (Dropout)           (None, 18, 18, 66)   0           ['max_pooling2d_10[0][0]']
#
#  batch_normalization_170 (Batch  (None, 18, 18, 66)  264         ['dropout_16[0][0]']
#  Normalization)
#
#  conv2d_87 (Conv2D)             (None, 18, 18, 79)   47005       ['batch_normalization_170[0][0]']
#
#  batch_normalization_171 (Batch  (None, 18, 18, 79)  316         ['conv2d_87[0][0]']
#  Normalization)
#
#  leaky_re_lu_86 (LeakyReLU)     (None, 18, 18, 79)   0           ['batch_normalization_171[0][0]']
#
#  leaky_re_lu_87 (LeakyReLU)     (None, 18, 18, 79)   0           ['leaky_re_lu_86[0][0]']
#
#  batch_normalization_172 (Batch  (None, 18, 18, 79)  316         ['leaky_re_lu_87[0][0]']
#  Normalization)
#
#  conv2d_88 (Conv2D)             (None, 18, 18, 79)   56248       ['batch_normalization_172[0][0]']
#
#  batch_normalization_174 (Batch  (None, 18, 18, 79)  316         ['conv2d_88[0][0]']
#  Normalization)
#
#  leaky_re_lu_88 (LeakyReLU)     (None, 18, 18, 79)   0           ['batch_normalization_174[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 18, 18, 79)   56248       ['leaky_re_lu_88[0][0]']
#
#  batch_normalization_175 (Batch  (None, 18, 18, 79)  316         ['conv2d_89[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 18, 18, 79)  316         ['leaky_re_lu_86[0][0]']
#  Normalization)
#
#  add_34 (Add)                   (None, 18, 18, 79)   0           ['batch_normalization_175[0][0]',
#                                                                   'batch_normalization_173[0][0]']
#
#  leaky_re_lu_89 (LeakyReLU)     (None, 18, 18, 79)   0           ['add_34[0][0]']
#
#  batch_normalization_176 (Batch  (None, 18, 18, 79)  316         ['leaky_re_lu_89[0][0]']
#  Normalization)
#
#  conv2d_90 (Conv2D)             (None, 18, 18, 79)   56248       ['batch_normalization_176[0][0]']
#
#  batch_normalization_178 (Batch  (None, 18, 18, 79)  316         ['conv2d_90[0][0]']
#  Normalization)
#
#  leaky_re_lu_90 (LeakyReLU)     (None, 18, 18, 79)   0           ['batch_normalization_178[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 18, 18, 79)   56248       ['leaky_re_lu_90[0][0]']
#
#  batch_normalization_179 (Batch  (None, 18, 18, 79)  316         ['conv2d_91[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (None, 18, 18, 79)  316         ['add_34[0][0]']
#  Normalization)
#
#  add_35 (Add)                   (None, 18, 18, 79)   0           ['batch_normalization_179[0][0]',
#                                                                   'batch_normalization_177[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 9, 9, 79)    0           ['add_35[0][0]']
#  )
#
#  dropout_17 (Dropout)           (None, 9, 9, 79)     0           ['max_pooling2d_11[0][0]']
#
#  batch_normalization_180 (Batch  (None, 9, 9, 79)    316         ['dropout_17[0][0]']
#  Normalization)
#
#  conv2d_92 (Conv2D)             (None, 9, 9, 95)     67640       ['batch_normalization_180[0][0]']
#
#  batch_normalization_181 (Batch  (None, 9, 9, 95)    380         ['conv2d_92[0][0]']
#  Normalization)
#
#  leaky_re_lu_91 (LeakyReLU)     (None, 9, 9, 95)     0           ['batch_normalization_181[0][0]']
#
#  leaky_re_lu_92 (LeakyReLU)     (None, 9, 9, 95)     0           ['leaky_re_lu_91[0][0]']
#
#  batch_normalization_182 (Batch  (None, 9, 9, 95)    380         ['leaky_re_lu_92[0][0]']
#  Normalization)
#
#  conv2d_93 (Conv2D)             (None, 9, 9, 95)     81320       ['batch_normalization_182[0][0]']
#
#  batch_normalization_184 (Batch  (None, 9, 9, 95)    380         ['conv2d_93[0][0]']
#  Normalization)
#
#  leaky_re_lu_93 (LeakyReLU)     (None, 9, 9, 95)     0           ['batch_normalization_184[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 9, 9, 95)     81320       ['leaky_re_lu_93[0][0]']
#
#  batch_normalization_185 (Batch  (None, 9, 9, 95)    380         ['conv2d_94[0][0]']
#  Normalization)
#
#  batch_normalization_183 (Batch  (None, 9, 9, 95)    380         ['leaky_re_lu_91[0][0]']
#  Normalization)
#
#  add_36 (Add)                   (None, 9, 9, 95)     0           ['batch_normalization_185[0][0]',
#                                                                   'batch_normalization_183[0][0]']
#
#  leaky_re_lu_94 (LeakyReLU)     (None, 9, 9, 95)     0           ['add_36[0][0]']
#
#  batch_normalization_186 (Batch  (None, 9, 9, 95)    380         ['leaky_re_lu_94[0][0]']
#  Normalization)
#
#  conv2d_95 (Conv2D)             (None, 9, 9, 95)     81320       ['batch_normalization_186[0][0]']
#
#  batch_normalization_188 (Batch  (None, 9, 9, 95)    380         ['conv2d_95[0][0]']
#  Normalization)
#  leaky_re_lu_95 (LeakyReLU)     (None, 9, 9, 95)     0           ['batch_normalization_188[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 9, 9, 95)     81320       ['leaky_re_lu_95[0][0]']
#
#  batch_normalization_189 (Batch  (None, 9, 9, 95)    380         ['conv2d_96[0][0]']
#  Normalization)
#
#  batch_normalization_187 (Batch  (None, 9, 9, 95)    380         ['add_36[0][0]']
#  Normalization)
#
#  add_37 (Add)                   (None, 9, 9, 95)     0           ['batch_normalization_189[0][0]',
#                                                                   'batch_normalization_187[0][0]']
#
#  dropout_18 (Dropout)           (None, 9, 9, 95)     0           ['add_37[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 18, 18, 79)  30099       ['dropout_18[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 18, 18, 158)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'add_35[0][0]']
#
#  batch_normalization_190 (Batch  (None, 18, 18, 158)  632        ['concatenate_6[0][0]']
#  Normalization)
#
#  conv2d_97 (Conv2D)             (None, 18, 18, 79)   112417      ['batch_normalization_190[0][0]']
#
#  batch_normalization_191 (Batch  (None, 18, 18, 79)  316         ['conv2d_97[0][0]']
#  Normalization)
#
#  leaky_re_lu_96 (LeakyReLU)     (None, 18, 18, 79)   0           ['batch_normalization_191[0][0]']
#
#  leaky_re_lu_97 (LeakyReLU)     (None, 18, 18, 79)   0           ['leaky_re_lu_96[0][0]']
#
#  batch_normalization_192 (Batch  (None, 18, 18, 79)  316         ['leaky_re_lu_97[0][0]']
#  Normalization)
#
#  conv2d_98 (Conv2D)             (None, 18, 18, 79)   56248       ['batch_normalization_192[0][0]']
#
#  batch_normalization_194 (Batch  (None, 18, 18, 79)  316         ['conv2d_98[0][0]']
#  Normalization)
#
#  leaky_re_lu_98 (LeakyReLU)     (None, 18, 18, 79)   0           ['batch_normalization_194[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 18, 18, 79)   56248       ['leaky_re_lu_98[0][0]']
#
#  batch_normalization_195 (Batch  (None, 18, 18, 79)  316         ['conv2d_99[0][0]']
#  Normalization)
#
#  batch_normalization_193 (Batch  (None, 18, 18, 79)  316         ['leaky_re_lu_96[0][0]']
#  Normalization)
#
#  add_38 (Add)                   (None, 18, 18, 79)   0           ['batch_normalization_195[0][0]',
#                                                                   'batch_normalization_193[0][0]']
#
#  leaky_re_lu_99 (LeakyReLU)     (None, 18, 18, 79)   0           ['add_38[0][0]']
#
#  batch_normalization_196 (Batch  (None, 18, 18, 79)  316         ['leaky_re_lu_99[0][0]']
#  Normalization)
#
#  conv2d_100 (Conv2D)            (None, 18, 18, 79)   56248       ['batch_normalization_196[0][0]']
#
#  batch_normalization_198 (Batch  (None, 18, 18, 79)  316         ['conv2d_100[0][0]']
#  Normalization)
#
#  leaky_re_lu_100 (LeakyReLU)    (None, 18, 18, 79)   0           ['batch_normalization_198[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 18, 18, 79)   56248       ['leaky_re_lu_100[0][0]']
#
#  batch_normalization_199 (Batch  (None, 18, 18, 79)  316         ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_197 (Batch  (None, 18, 18, 79)  316         ['add_38[0][0]']
# ...
#
#  batch_normalization_227 (Batch  (None, 144, 144, 45  180        ['add_44[0][0]']
#  Normalization)                 )
#
#  add_45 (Add)                   (None, 144, 144, 45  0           ['batch_normalization_229[0][0]',
#                                 )                                 'batch_normalization_227[0][0]']
#
#  dropout_22 (Dropout)           (None, 144, 144, 45  0           ['add_45[0][0]']
#                                 )
#
#  conv2d_transpose_10 (Conv2DTra  (None, 288, 288, 37  6697       ['dropout_22[0][0]']
#  nspose)                        )
#
#  concatenate_10 (Concatenate)   (None, 288, 288, 75  0           ['conv2d_transpose_10[0][0]',
#                                 )                                 'add_27[0][0]']
#
#  batch_normalization_230 (Batch  (None, 288, 288, 75  300        ['concatenate_10[0][0]']
#  Normalization)                 )
#
#  conv2d_117 (Conv2D)            (None, 288, 288, 37  25012       ['batch_normalization_230[0][0]']
#                                 )
#
#  batch_normalization_231 (Batch  (None, 288, 288, 37  148        ['conv2d_117[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_116 (LeakyReLU)    (None, 288, 288, 37  0           ['batch_normalization_231[0][0]']
#                                 )
#
#  leaky_re_lu_117 (LeakyReLU)    (None, 288, 288, 37  0           ['leaky_re_lu_116[0][0]']
#                                 )
#
#  batch_normalization_232 (Batch  (None, 288, 288, 37  148        ['leaky_re_lu_117[0][0]']
#  Normalization)                 )
#
#  conv2d_118 (Conv2D)            (None, 288, 288, 37  12358       ['batch_normalization_232[0][0]']
#                                 )
#
#  batch_normalization_234 (Batch  (None, 288, 288, 37  148        ['conv2d_118[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_118 (LeakyReLU)    (None, 288, 288, 37  0           ['batch_normalization_234[0][0]']
#                                 )
#
#  conv2d_119 (Conv2D)            (None, 288, 288, 37  12358       ['leaky_re_lu_118[0][0]']
#                                 )
#
#  batch_normalization_235 (Batch  (None, 288, 288, 37  148        ['conv2d_119[0][0]']
#  Normalization)                 )
#
#  batch_normalization_233 (Batch  (None, 288, 288, 37  148        ['leaky_re_lu_116[0][0]']
#  Normalization)                 )
#
#  add_46 (Add)                   (None, 288, 288, 37  0           ['batch_normalization_235[0][0]',
#                                 )                                 'batch_normalization_233[0][0]']
#
#  leaky_re_lu_119 (LeakyReLU)    (None, 288, 288, 37  0           ['add_46[0][0]']
#                                 )
#
#  batch_normalization_236 (Batch  (None, 288, 288, 37  148        ['leaky_re_lu_119[0][0]']
#  Normalization)                 )
#
#  conv2d_120 (Conv2D)            (None, 288, 288, 37  12358       ['batch_normalization_236[0][0]']
#                                 )
#
#  batch_normalization_238 (Batch  (None, 288, 288, 37  148        ['conv2d_120[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_120 (LeakyReLU)    (None, 288, 288, 37  0           ['batch_normalization_238[0][0]']
#                                 )
#
#  conv2d_121 (Conv2D)            (None, 288, 288, 37  12358       ['leaky_re_lu_120[0][0]']
#                                 )
#
#  batch_normalization_239 (Batch  (None, 288, 288, 37  148        ['conv2d_121[0][0]']
#  Normalization)                 )
#
#  batch_normalization_237 (Batch  (None, 288, 288, 37  148        ['add_46[0][0]']
#  Normalization)                 )
#
#  add_47 (Add)                   (None, 288, 288, 37  0           ['batch_normalization_239[0][0]',
#                                 )                                 'batch_normalization_237[0][0]']
#
#  dropout_23 (Dropout)           (None, 288, 288, 37  0           ['add_47[0][0]']
#                                 )
#
#  conv2d_transpose_11 (Conv2DTra  (None, 576, 576, 30  4470       ['dropout_23[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 576, 576, 62  0           ['conv2d_transpose_11[0][0]',
#                                 )                                 'add_25[0][0]']
#
#  batch_normalization_240 (Batch  (None, 576, 576, 62  248        ['concatenate_11[0][0]']
#  Normalization)                 )
#
#  conv2d_122 (Conv2D)            (None, 576, 576, 30  16770       ['batch_normalization_240[0][0]']
#                                 )
#
#  batch_normalization_241 (Batch  (None, 576, 576, 30  120        ['conv2d_122[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_121 (LeakyReLU)    (None, 576, 576, 30  0           ['batch_normalization_241[0][0]']
#                                 )
#
#  leaky_re_lu_122 (LeakyReLU)    (None, 576, 576, 30  0           ['leaky_re_lu_121[0][0]']
#                                 )
#
#  batch_normalization_242 (Batch  (None, 576, 576, 30  120        ['leaky_re_lu_122[0][0]']
#  Normalization)                 )
#
#  conv2d_123 (Conv2D)            (None, 576, 576, 30  8130        ['batch_normalization_242[0][0]']
#                                 )
#
#  batch_normalization_244 (Batch  (None, 576, 576, 30  120        ['conv2d_123[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_123 (LeakyReLU)    (None, 576, 576, 30  0           ['batch_normalization_244[0][0]']
#                                 )
#
#  conv2d_124 (Conv2D)            (None, 576, 576, 30  8130        ['leaky_re_lu_123[0][0]']
#                                 )
#
#  batch_normalization_245 (Batch  (None, 576, 576, 30  120        ['conv2d_124[0][0]']
#  Normalization)                 )
#
#  batch_normalization_243 (Batch  (None, 576, 576, 30  120        ['leaky_re_lu_121[0][0]']
#  Normalization)                 )
#
#  add_48 (Add)                   (None, 576, 576, 30  0           ['batch_normalization_245[0][0]',
#                                 )                                 'batch_normalization_243[0][0]']
#
#  leaky_re_lu_124 (LeakyReLU)    (None, 576, 576, 30  0           ['add_48[0][0]']
#                                 )
#
#  batch_normalization_246 (Batch  (None, 576, 576, 30  120        ['leaky_re_lu_124[0][0]']
#  Normalization)                 )
#
#  conv2d_125 (Conv2D)            (None, 576, 576, 30  8130        ['batch_normalization_246[0][0]']
#                                 )
#
#  batch_normalization_248 (Batch  (None, 576, 576, 30  120        ['conv2d_125[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_125 (LeakyReLU)    (None, 576, 576, 30  0           ['batch_normalization_248[0][0]']
#                                 )
#
#  conv2d_126 (Conv2D)            (None, 576, 576, 30  8130        ['leaky_re_lu_125[0][0]']
#                                 )
#
#  batch_normalization_249 (Batch  (None, 576, 576, 30  120        ['conv2d_126[0][0]']
#  Normalization)                 )
#
#  batch_normalization_247 (Batch  (None, 576, 576, 30  120        ['add_48[0][0]']
#  Normalization)                 )
#
#  add_49 (Add)                   (None, 576, 576, 30  0           ['batch_normalization_249[0][0]',
#                                 )                                 'batch_normalization_247[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 576, 576, 1)  31          ['add_49[0][0]']
#
# ==================================================================================================
# Total params: 2,234,702
# Trainable params: 2,220,096
# Non-trainable params: 14,606
# __________________________________________________________________________________________________

# %%
for i in range(10):
    model.fit(train_gen, use_multiprocessing=True, workers=8)
    res = model.evaluate(test_gen)
    iou = "{:.3f}".format(res[1])
    model.save_weights(f"/media/nathan/LaCie/Data/models/model_deepres_x8_576_e{i}_iou{iou}.h5")
# Out:
#   5/188 [..............................] - ETA: 1:22:58 - loss: 1.7711 - iou_score: 0.3674

# %%
res = model.evaluate(test_gen)

# %%
# model.load_weights("/media/nathan/LaCie/Data/models/model_deep_x8_576_e8_iou0.793.h5")

# %%
preds = model.predict(test_gen)

# %%
b = test_gen[0]

len(b[0])

show_batch((b[0], preds[:4]))

# %%
show_batch(b)
