# %%
import tensorflow as tf
for gpu in tf.config.list_physical_devices("GPU"):
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2022-09-05 11:58:41.622012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 11:58:41.642790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-05 11:58:41.642892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
from brainseg.models import siamese
from tensorflow.keras import optimizers

from brainseg.handlers.siamese_histo_mri import (SiameseHistoMRIHandler2, list_descriptors,
                                                 extract_monkey_from_mri, list_descriptors_histo_only,
                                                 list_descriptors_mri_only,
                                                 SelfHistoMRIHandler)
from brainseg.provider import provider
from brainseg.loader import Loader
from brainseg.generator import X0TrainGenerator, XTestGenerator
import glob
import pandas as pd
import numpy as np

from random import sample, choices, choice
from math import floor
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import imgaug.augmenters as iaa
from skimage.transform import resize

# %%
HISTO_LOCATION = "/media/moi/KINGSTON/BrainMapping/slides_512_self/*"

# %%
slides = glob.glob(HISTO_LOCATION)

# %%
desc = list_descriptors_histo_only(slides)

# %%
desc
# Out:
# [{'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH141_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 141},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH129-RH127.png',
#   'monkey_name': 'M144',
#   'slide_id': 127},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH125-RH123.png',
#   'monkey_name': 'M144',
#   'slide_id': 123},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH181-RH179.png',
#   'monkey_name': 'M144',
#   'slide_id': 179},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH133-RH131.png',
#   'monkey_name': 'M144',
#   'slide_id': 131},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH177-RH175.png',
#   'monkey_name': 'M144',
#   'slide_id': 175},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH289_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 289},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH225-RH223.png',
#   'monkey_name': 'M144',
#   'slide_id': 223},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH229-RH227.png',
#   'monkey_name': 'M144',
#   'slide_id': 227},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH233-RH231.png',
#   'monkey_name': 'M144',
#   'slide_id': 231},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH237-RH235.png',
#   'monkey_name': 'M144',
#   'slide_id': 235},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH241-RH239.png',
#   'monkey_name': 'M144',
#   'slide_id': 239},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH245-RH243.png',
#   'monkey_name': 'M144',
#   'slide_id': 243},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH253-RH251.png',
#   'monkey_name': 'M144',
#   'slide_id': 251},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH256.png',
#   'monkey_name': 'M144',
#   'slide_id': 256},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH257-RH255.png',
#   'monkey_name': 'M144',
#   'slide_id': 255},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH261-RH259.png',
#   'monkey_name': 'M144',
#   'slide_id': 259},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH265-RH263.png',
#   'monkey_name': 'M144',
#   'slide_id': 263},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH269-RH267.png',
#   'monkey_name': 'M144',
#   'slide_id': 267},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH277-RH275.png',
#   'monkey_name': 'M144',
#   'slide_id': 275},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH281-RH279.png',
#   'monkey_name': 'M144',
#   'slide_id': 279},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH285-RH283.png',
#   'monkey_name': 'M144',
#   'slide_id': 283},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH289-RH287.png',
#   'monkey_name': 'M144',
#   'slide_id': 287},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH293-RH291.png',
#   'monkey_name': 'M144',
#   'slide_id': 291},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH297-RH295.png',
#   'monkey_name': 'M144',
#   'slide_id': 295},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH301-RH299.png',
#   'monkey_name': 'M144',
#   'slide_id': 299},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LHRH052.png',
#   'monkey_name': 'M144',
#   'slide_id': 52},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LHRH056.png',
#   'monkey_name': 'M144',
#   'slide_id': 56},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LHRH060.png',
#   'monkey_name': 'M144',
#   'slide_id': 60},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LHRH064.png',
#   'monkey_name': 'M144',
#   'slide_id': 64},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/C060-147-CV.png',
#   'monkey_name': 'C060',
#   'slide_id': 147},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/C060-149-CV.png',
#   'monkey_name': 'C060',
#   'slide_id': 149},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/C060-151-CV.png',
#   'monkey_name': 'C060',
#   'slide_id': 151},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/C060
CV.png',
#   'monkey_name': 'C060',
#   'slide_id': 523},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/C060-525-CV.png',
#   'monkey_name': 'C060',
#   'slide_id': 525},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/C060-527-CV.png',
#   'monkey_name': 'C060',
#   'slide_id': 527},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH079_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 79},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH083_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 83},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH087_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 87},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH091_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 91},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH095_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 95},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH099_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 99},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH103_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 103},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH107_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 107},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH111_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 111},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH115_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 115},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH117_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 117},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH121_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 121},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH125_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 125},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH129_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 129},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH133_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 133},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH137_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 137},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH145_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 145},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH149_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 149},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH153_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 153},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH157_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 157},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH161_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 161},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH165_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 165},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH169_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 169},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH173_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 173},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH177_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 177},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH185_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 185},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH189_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 189},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH193_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 193},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH197_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 197},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH201_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 201},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH205_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 205},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH209_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 209},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH213_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 213},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH217_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 217},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH221_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 221},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH225_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 225},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH229_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 229},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH233_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 233},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH237_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 237},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH241_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 241},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH245_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 245},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH249_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 249},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH253_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 253},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH257_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 257},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH261_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 261},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH265_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 265},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH269_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 269},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH273_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 273},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH277_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 277},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH281_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 281},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH285_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 285},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH293_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 293},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH297_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 297},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH301_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 301},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH309_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 309},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH313_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 313},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH317_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 317},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH321_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 321},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH323_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 323},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH327_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 327},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M155_LHRH331_CV.png',
#   'monkey_name': 'M155',
#   'slide_id': 331},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH117-RH115.png',
#   'monkey_name': 'M144',
#   'slide_id': 115},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH121-RH119.png',
#   'monkey_name': 'M144',
#   'slide_id': 119},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH221-RH219.png',
#   'monkey_name': 'M144',
#   'slide_id': 219},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH209-RH207.png',
#   'monkey_name': 'M144',
#   'slide_id': 207},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH205-RH203.png',
#   'monkey_name': 'M144',
#   'slide_id': 203},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH193-RH191.png',
#   'monkey_name': 'M144',
#   'slide_id': 191},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH189-RH187.png',
#   'monkey_name': 'M144',
#   'slide_id': 187},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH185-RH183.png',
#   'monkey_name': 'M144',
#   'slide_id': 183},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH273-RH271.png',
#   'monkey_name': 'M144',
#   'slide_id': 271},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH249-RH247.png',
#   'monkey_name': 'M144',
#   'slide_id': 247},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH201-RH199.png',
#   'monkey_name': 'M144',
#   'slide_id': 199},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH197-RH195.png',
#   'monkey_name': 'M144',
#   'slide_id': 195},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH173-RH171.png',
#   'monkey_name': 'M144',
#   'slide_id': 171},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH169-RH167.png',
#   'monkey_name': 'M144',
#   'slide_id': 167},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH165-RH163.png',
#   'monkey_name': 'M144',
#   'slide_id': 163},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH161-RH159.png',
#   'monkey_name': 'M144',
#   'slide_id': 159},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH157-RH155.png',
#   'monkey_name': 'M144',
#   'slide_id': 155},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH153-RH151.png',
#   'monkey_name': 'M144',
#   'slide_id': 151},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH149-RH147.png',
#   'monkey_name': 'M144',
#   'slide_id': 147},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH145-RH143.png',
#   'monkey_name': 'M144',
#   'slide_id': 143},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH141-RH139.png',
#   'monkey_name': 'M144',
#   'slide_id': 139},
#  {'image_name': '/media/moi/KINGSTON/BrainMapping/slides_512_self/M144-LH137-RH135.png',
#   'monkey_name': 'M144',
#   'slide_id': 135}]

# %% [markdown]
# ## Setup enlargement for MRI images

# %%
import glob
import os

# %%
def get_oasis_id(path):
    return path.split("/")[-5]

def oasis_path_to_mask(path):
    return path.replace("t88_gfc", "t88_masked_gfc")

# %%
files = glob.glob("/home/moi/Downloads/oasis/*/*/*/PROCESSED/MPRAGE/T88_111/*t88_gfc.hdr")
len(files)
# Out:
# 108

# %%
get_oasis_id(files[0])
# Out:
# 'OAS1_0370_MR1'

# %%
oasis_path_to_mask(files[0])
# Out:
# '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_masked_gfc.hdr'

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# %%
desc_mri = list_descriptors_mri_only(files)
len(desc_mri)
# Out:
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.402 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.403 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.413 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.414 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.422 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.423 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.432 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.433 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.442 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.443 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.452 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.453 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.462 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.463 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.472 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.473 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.483 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.484 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.493 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.494 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.503 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.504 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.513 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.514 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.523 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.524 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.533 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.534 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.543 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.545 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.555 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.556 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.565 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.566 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.574 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.575 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.585 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.586 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.595 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.596 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.605 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.606 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.616 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.617 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.627 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.628 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.637 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.638 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.648 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.649 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.658 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.659 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.668 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.669 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.679 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.680 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.689 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.690 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.699 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.700 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.709 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.710 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.719 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.720 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.729 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.730 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.739 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.740 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.750 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.752 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.775 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.776 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.789 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.790 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.802 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.803 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.816 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.817 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.829 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.830 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.842 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.843 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.855 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.857 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.871 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.872 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.884 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.885 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.898 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.899 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.910 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.911 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.924 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.925 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.937 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.938 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.950 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.951 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.964 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.965 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.976 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.978 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.990 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:01.991 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.003 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.004 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.015 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.016 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.028 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.029 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.041 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.042 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.053 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.054 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.067 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.068 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.079 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.080 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.091 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.092 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.104 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.105 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.120 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.121 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.135 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.136 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.150 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.151 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.165 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.166 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.177 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.178 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.190 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.191 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.204 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.205 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.217 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.218 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.230 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.231 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.242 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.243 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.255 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.256 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.268 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.269 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.280 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.281 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.293 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.294 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.303 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.304 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.312 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.313 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.322 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.323 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.332 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.333 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.341 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.342 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.351 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.352 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.361 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.362 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.371 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.372 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.381 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.382 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.391 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.392 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.403 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.404 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.413 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.414 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.424 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.425 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.433 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.434 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.443 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.444 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.454 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.455 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.463 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.464 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.472 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.473 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.482 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.483 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.492 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.493 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.502 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.503 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.511 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.512 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.520 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.522 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.532 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.533 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.542 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.543 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.552 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.553 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.562 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.563 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.573 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.574 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.583 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.584 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.593 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.594 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.604 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.605 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.614 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.615 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.624 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# very large origin values relative to dims; leaving as set, ignoring for affine
# 2022-09-05 12:01:02.624 INFO    nibabel.global: very large origin values relative to dims; leaving as set, ignoring for affine
# 18144

# %%
desc_mri[:10]
# Out:
# [{'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 20,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 20,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 21,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 21,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 22,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 22,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 23,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 23,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 24,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 24,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 25,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 25,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 26,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 26,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 27,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 27,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 28,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 28,
#   'has_mask': True},
#  {'mri_name': '/home/moi/Downloads/oasis/oasis_cross-sectional_disc10/disc10/OAS1_0370_MR1/PROCESSED/MPRAGE/T88_111/OAS1_0370_MR1_mpr_n3_anon_111_t88_gfc.hdr',
#   'slide_id': 29,
#   'rotx': 0,
#   'rotz': 0,
#   'mri_id': 29,
#   'has_mask': True}]
